# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install datasets
# !pip install transformers
# !pip install peft
# !pip install evaluate
# !pip install -U datasets==2.20.0 pyarrow==15.0.2 transformers==4.44.2 evaluate==0.4.2 --no-cache-dir
# !pip install -q datasets evaluate accelerate scikit-learn pandas matplotlib
# !pip install -U "transformers>=4.41" accelerate safetensors
# !pip install -U bitsandbytes
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from peft) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft) (6.0.3)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft) (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft) (4.57.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft) (1.12.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from peft) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (0.22.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (2025.11.12)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6
# Collecting datasets==2.20.0
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Collecting pyarrow==15.0.2
#   Downloading pyarrow-15.0.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting transformers==4.44.2
#   Downloading transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 258.0 MB/s eta 0:00:00
# Collecting evaluate==0.4.2
#   Downloading evaluate-0.4.2-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (2.0.2)
# Collecting pyarrow-hotfix (from datasets==2.20.0)
#   Downloading pyarrow_hotfix-0.7-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (0.70.16)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets==2.20.0)
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (3.13.2)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0) (6.0.3)
# Collecting numpy>=1.17 (from datasets==2.20.0)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 315.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (0.7.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.44.2)
#   Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0) (1.22.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets==2.20.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets==2.20.0) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.20.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.20.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.20.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.20.0) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.20.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.20.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.20.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.20.0) (1.17.0)
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 42.5 MB/s eta 0:00:00
# Downloading pyarrow-15.0.2-cp312-cp312-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 263.2 MB/s eta 0:00:00a 0:00:01
# Downloading transformers-4.44.2-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 241.5 MB/s eta 0:00:00a 0:00:01
# Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 335.6 MB/s eta 0:00:00
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 400.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 167.9 MB/s eta 0:00:00a 0:00:01
# Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 184.6 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.7-py3-none-any.whl (7.9 kB)
# Installing collected packages: pyarrow-hotfix, numpy, fsspec, pyarrow, tokenizers, transformers, datasets, evaluate
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.2
#     Uninstalling transformers-4.57.2:
#       Successfully uninstalled transformers-4.57.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: evaluate
#     Found existing installation: evaluate 0.4.6
#     Uninstalling evaluate-0.4.6:
#       Successfully uninstalled evaluate-0.4.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.5.0 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed datasets-2.20.0 evaluate-0.4.2 fsspec-2024.5.0 numpy-1.26.4 pyarrow-15.0.2 pyarrow-hotfix-0.7 tokenizers-0.19.1 transformers-4.44.2
# Requirement already satisfied: transformers>=4.41 in /usr/local/lib/python3.12/dist-packages (4.44.2)
# Collecting transformers>=4.41
#   Downloading transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41) (2.32.4)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers>=4.41)
#   Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.41) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.9.0+cu126)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.41) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.41) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.41) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.41) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.41) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.41) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.41) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 133.8 MB/s eta 0:00:0000:010:01
# Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 114.3 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# Successfully installed tokenizers-0.22.1 transformers-4.57.3
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.9.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Downloading bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl (59.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 20.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.48.2

# %%
# !pip install --upgrade --no-cache-dir git+https://github.com/Shannu3766/bi_influence.git
# !pip install --upgrade --no-cache-dir git+https://github.com/Shannu3766/Cosine-similarity.git
# !pip uninstall adalora_bi_eq13 -y
# Out:
# Collecting git+https://github.com/Shannu3766/Cosine-similarity.git
#   Cloning https://github.com/Shannu3766/Cosine-similarity.git to /tmp/pip-req-build-bshbd81c
#   Running command git clone --filter=blob:none --quiet https://github.com/Shannu3766/Cosine-similarity.git /tmp/pip-req-build-bshbd81c
#   Resolved https://github.com/Shannu3766/Cosine-similarity.git to commit 913cc8243a93908a0e7ab258562fdc7695f1eb1a
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from adalora_bi_eq13==0.1.0) (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from adalora_bi_eq13==0.1.0) (4.57.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from adalora_bi_eq13==0.1.0) (2.20.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from adalora_bi_eq13==0.1.0) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from adalora_bi_eq13==0.1.0) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets->adalora_bi_eq13==0.1.0) (2024.5.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (3.13.2)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets->adalora_bi_eq13==0.1.0) (6.0.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->adalora_bi_eq13==0.1.0) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->adalora_bi_eq13==0.1.0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->adalora_bi_eq13==0.1.0) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->adalora_bi_eq13==0.1.0) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->adalora_bi_eq13==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->adalora_bi_eq13==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->adalora_bi_eq13==0.1.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->adalora_bi_eq13==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->adalora_bi_eq13==0.1.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->adalora_bi_eq13==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets->adalora_bi_eq13==0.1.0) (1.22.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets->adalora_bi_eq13==0.1.0) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->adalora_bi_eq13==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->adalora_bi_eq13==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->adalora_bi_eq13==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->adalora_bi_eq13==0.1.0) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->adalora_bi_eq13==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->adalora_bi_eq13==0.1.0) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->adalora_bi_eq13==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->adalora_bi_eq13==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->adalora_bi_eq13==0.1.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->adalora_bi_eq13==0.1.0) (1.17.0)
# Building wheels for collected packages: adalora_bi_eq13
#   Building wheel for adalora_bi_eq13 (setup.py) ... done
#   Created wheel for adalora_bi_eq13: filename=adalora_bi_eq13-0.1.0-py3-none-any.whl size=10253 sha256=0dcdbd7080c75b5db4376e109cee8545f2b3972319eba286b60b5b0674b27f46
#   Stored in directory: /tmp/pip-ephem-wheel-cache-82pfn0m0/wheels/7e/9d/f3/13898734a779d7b427419fa0ff63bf393a2a18fb8f70a46662
# Successfully built adalora_bi_eq13
# Installing collected packages: adalora_bi_eq13
# Successfully installed adalora_bi_eq13-0.1.0

# %%
# !pip uninstall adalora_bi_eq13 -y

# %%
import warnings
import os
import logging
os.environ["WANDB_DISABLED"] = "true"
os.environ["TRANSFORMERS_NO_ADVISORY_WARNINGS"] = "true"
os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"
os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings("ignore")
# logging.set_verbosity_error()

# %%
import os
import torch
import numpy as np
import evaluate
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    TrainingArguments,
    Trainer
)
from peft import get_peft_model, LoraConfig, TaskType
os.environ["WANDB_DISABLED"] = "true"

# %%
MODEL_ID = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
TASK = "rte"
LR = 2e-4
NUM_EPOCHS = 5
BATCH_SIZE = 8 
MAX_LEN = 256  
rank= 8

# %%
import time
def load_dataset_with_retry(path, name=None, max_retries=None, wait=2):
    """
    Repeatedly tries to load a dataset until it succeeds.
    - max_retries: None → infinite retries
    - wait: base wait time (exponential backoff)
    """
    attempt = 0

    while True:
        try:
            if name is not None:
                ds = load_dataset(path, name)
            else:
                ds = load_dataset(path)

            print(f"Dataset loaded successfully after {attempt} attempts.")
            return ds

        except Exception as e:
            attempt += 1
            wait_time = wait * min(5, attempt)  # exponential cap

            print(f"[Attempt {attempt}] Failed to load dataset: {e}")
            print(f"Retrying in {wait_time} seconds...\n")

            # If user gives a max_retries limit
            if max_retries is not None and attempt >= max_retries:
                print("Max retries reached. Raising error.")
                raise e

            time.sleep(wait_time)

dataset = load_dataset_with_retry("glue", TASK)
# Out:
# Dataset loaded successfully after 0 attempts.

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence1', 'sentence2', 'label', 'idx'],
#         num_rows: 2490
#     })
#     validation: Dataset({
#         features: ['sentence1', 'sentence2', 'label', 'idx'],
#         num_rows: 277
#     })
#     test: Dataset({
#         features: ['sentence1', 'sentence2', 'label', 'idx'],
#         num_rows: 3000
#     })
# })

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True)

# %%
from transformers import DataCollatorWithPadding

# Make sure pad token exists for TinyLlama
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

MAX_LEN = 256  # enough for RTE, avoids over-long sequences


def clean_text(s):
    if s is None:
        return ""
    # strip + collapse multiple spaces/newlines
    return " ".join(str(s).strip().split())


def preprocess_function(examples):
    premises = [clean_text(p) for p in examples["sentence1"]]
    hypotheses = [clean_text(h) for h in examples["sentence2"]]

    # Clear, instruction-like prompt with an explicit "Answer:"
    inputs = [
        (
            f"Premise: {p}\n"
            f"Hypothesis: {h}\n"
            f"Question: Does the premise entail the hypothesis?\n"
            f"Answer:"
        )
        for p, h in zip(premises, hypotheses)
    ]

    tokenized = tokenizer(
        inputs,
        truncation=True,
        max_length=MAX_LEN,
        padding=False,
    )
    return tokenized


# Map over the dataset
encoded_dataset = dataset.map(preprocess_function, batched=True)

# Drop original text columns
encoded_dataset = encoded_dataset.remove_columns(["sentence1", "sentence2", "idx"])

# Make sure labels column is named "labels"
if "label" in encoded_dataset["train"].column_names and "labels" not in encoded_dataset["train"].column_names:
    encoded_dataset = encoded_dataset.rename_column("label", "labels")

encoded_dataset.set_format("torch")

# Use dynamic padding at batch level
data_collator = DataCollatorWithPadding(
    tokenizer=tokenizer,
    padding="longest",
)
# Out:
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]

# %%
print("Model started Loading")
# Out:
# Model started Loading

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_ID,
    num_labels=2,
    device_map="auto",
    torch_dtype=torch.bfloat16, 
    trust_remote_code=True
)

print("Model Loaded")
model.config.pad_token_id = tokenizer.pad_token_id
model.config.use_cache = False
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Some weights of LlamaForSequenceClassification were not initialized from the model checkpoint at TinyLlama/TinyLlama-1.1B-Chat-v1.0 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model Loaded

# %%
print("Model Loaded")
model.config.pad_token_id = tokenizer.pad_token_id
model.config.use_cache = False
# Out:
# Model Loaded

# %%
peft_config = LoraConfig(
    task_type=TaskType.SEQ_CLS,
    r=rank,                    
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    target_modules=[   
        "q_proj", "k_proj", "v_proj", "o_proj", 
        "gate_proj", "up_proj", "down_proj"
    ]
)

# %%
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)
# Out:
# trainable params: 6,311,936 || all params: 1,040,828,416 || trainable%: 0.6064

# %%
from peft.tuners.lora import LoraLayer

def get_lora_module_names(peft_model):
    names = []
    for name, module in peft_model.named_modules():
        if isinstance(module, LoraLayer):
            names.append(name)
    return names

lora_names = get_lora_module_names(model)   # `model` is your PEFT-wrapped model
print(f"🔢 Number of LoRA modules: {len(lora_names)}\n")

# for n in lora_names:
    # print(" ", n)
num_lora_modules = len(lora_names)
TOTAL_RANK_BUDGET = rank*num_lora_modules  # example

avg_rank_per_module = TOTAL_RANK_BUDGET / num_lora_modules
print(
    f"💡 With TOTAL_RANK_BUDGET={TOTAL_RANK_BUDGET} over "
    f"{num_lora_modules} modules, avg rank ≈ {avg_rank_per_module:.2f}"
)
# Out:
# 🔢 Number of LoRA modules: 154
#
# 💡 With TOTAL_RANK_BUDGET=1232 over 154 modules, avg rank ≈ 8.00

# %%
training_args = TrainingArguments(
    output_dir=f"{MODEL_ID}-RTE-v2",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=LR,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    num_train_epochs=NUM_EPOCHS,
    weight_decay=0.01,
    logging_steps=20,
    metric_for_best_model="accuracy",
    fp16=False,             
    bf16=True,      
    report_to="none",
)

# %%
from torch.utils.data import DataLoader
from transformers import DataCollatorWithPadding
from adaptive_lora_gradient.callbacks import AdaptiveLoRACallback
import torch

# -----------------------------
# 🧹 1. Clean up the dataset
# -----------------------------

# Make sure labels are named "labels" once
if "label" in encoded_dataset["train"].column_names and "labels" not in encoded_dataset["train"].column_names:
    encoded_dataset = encoded_dataset.rename_column("label", "labels")

# TinyLlama is a decoder-only model → no token_type_ids
keep_cols = {"input_ids", "attention_mask", "labels"}

for split in encoded_dataset.keys():
    drop_cols = [c for c in encoded_dataset[split].column_names if c not in keep_cols]
    if drop_cols:
        encoded_dataset[split] = encoded_dataset[split].remove_columns(drop_cols)

encoded_dataset.set_format(type="torch")

# -----------------------------
# 🧱 2. Data Collator & Datasets
# -----------------------------

# Dynamic padding to the longest sequence per batch
data_collator = DataCollatorWithPadding(
    tokenizer=tokenizer,
    padding="longest",
)

train_dataset = encoded_dataset["train"]
eval_dataset = encoded_dataset["validation"]

# Match eval batch size to TrainingArguments if available
EVAL_BATCH_SIZE = getattr(training_args, "per_device_eval_batch_size", 8)

val_dataloader = DataLoader(
    eval_dataset,
    batch_size=EVAL_BATCH_SIZE,
    shuffle=False,
    collate_fn=data_collator,
    pin_memory=torch.cuda.is_available(),
    num_workers=2,
)

# -----------------------------
# 🔁 3. Adaptive LoRA Callback
# -----------------------------
adaptive_callback = AdaptiveLoRACallback(
    val_dataloader=val_dataloader,
    total_rank=TOTAL_RANK_BUDGET,        # much safer than 10000 for TinyLlama + tiny RTE
    tau=0.9,
    # min_rank=4,           
    # validate_batch_size=EVAL_BATCH_SIZE,
    verbose=True,
)

print("✅ Adaptive LoRA callback ready.")
# Out:
# ✅ Adaptive LoRA callback ready.

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=encoded_dataset["train"],
    eval_dataset=encoded_dataset["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[adaptive_callback],
)

print("🚀 Starting Training...")
trainer.train()
# Out:
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# 🚀 Starting Training...
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 1 ---
# Computing BI importance scores (pre-training)...
# Computing Importance:   0%|          | 0/35 [00:00<?, ?it/s]
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=8 → 6 (Score: 0.2029)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=8 → 7 (Score: 0.3335)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=8 → 7 (Score: 0.2829)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=8 → 10 (Score: 0.6787)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=8 (Unchanged, Score: 0.4031)
#   - base_model.model.model.layers.0.mlp.up_proj: r=8 → 7 (Score: 0.3945)
#   - base_model.model.model.layers.0.mlp.down_proj: r=8 → 7 (Score: 0.3946)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=8 → 7 (Score: 0.3642)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=8 → 12 (Score: 0.7953)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=8 (Unchanged, Score: 0.4674)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=8 (Unchanged, Score: 0.4728)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=8 (Unchanged, Score: 0.4160)
#   - base_model.model.model.layers.1.mlp.up_proj: r=8 (Unchanged, Score: 0.4015)
#   - base_model.model.model.layers.1.mlp.down_proj: r=8 (Unchanged, Score: 0.4016)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=8 (Unchanged, Score: 0.4063)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=8 → 13 (Score: 0.8719)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=8 (Unchanged, Score: 0.4330)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=8 (Unchanged, Score: 0.4001)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=8 (Unchanged, Score: 0.4911)
#   - base_model.model.model.layers.2.mlp.up_proj: r=8 (Unchanged, Score: 0.4657)
#   - base_model.model.model.layers.2.mlp.down_proj: r=8 (Unchanged, Score: 0.4653)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=8 → 13 (Score: 0.8561)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=8 (Unchanged, Score: 0.5051)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=8 → 7 (Score: 0.3718)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=8 → 7 (Score: 0.3318)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=8 (Unchanged, Score: 0.4438)
#   - base_model.model.model.layers.3.mlp.up_proj: r=8 (Unchanged, Score: 0.4137)
#   - base_model.model.model.layers.3.mlp.down_proj: r=8 (Unchanged, Score: 0.4137)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=8 → 11 (Score: 0.7777)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=8 (Unchanged, Score: 0.4354)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=8 → 7 (Score: 0.3064)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=8 → 7 (Score: 0.2804)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=8 (Unchanged, Score: 0.4883)
#   - base_model.model.model.layers.4.mlp.up_proj: r=8 (Unchanged, Score: 0.4744)
#   - base_model.model.model.layers.4.mlp.down_proj: r=8 (Unchanged, Score: 0.4742)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=8 → 11 (Score: 0.7505)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=8 (Unchanged, Score: 0.4176)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=8 → 7 (Score: 0.3259)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=8 → 7 (Score: 0.3362)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=8 (Unchanged, Score: 0.5025)
#   - base_model.model.model.layers.5.mlp.up_proj: r=8 (Unchanged, Score: 0.4918)
#   - base_model.model.model.layers.5.mlp.down_proj: r=8 (Unchanged, Score: 0.4919)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=8 → 13 (Score: 0.8677)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=8 (Unchanged, Score: 0.4758)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=8 (Unchanged, Score: 0.4583)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=8 → 7 (Score: 0.3186)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=8 (Unchanged, Score: 0.4846)
#   - base_model.model.model.layers.6.mlp.up_proj: r=8 (Unchanged, Score: 0.5019)
#   - base_model.model.model.layers.6.mlp.down_proj: r=8 (Unchanged, Score: 0.5020)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=8 → 10 (Score: 0.6851)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=8 → 9 (Score: 0.5631)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=8 (Unchanged, Score: 0.4751)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=8 → 7 (Score: 0.3520)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=8 → 11 (Score: 0.7675)
#   - base_model.model.model.layers.7.mlp.up_proj: r=8 → 10 (Score: 0.6935)
#   - base_model.model.model.layers.7.mlp.down_proj: r=8 → 10 (Score: 0.6936)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=8 → 10 (Score: 0.6506)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=8 (Unchanged, Score: 0.4432)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=8 → 7 (Score: 0.3760)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=8 → 7 (Score: 0.3200)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=8 (Unchanged, Score: 0.5026)
#   - base_model.model.model.layers.8.mlp.up_proj: r=8 (Unchanged, Score: 0.5003)
#   - base_model.model.model.layers.8.mlp.down_proj: r=8 (Unchanged, Score: 0.5002)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=8 → 10 (Score: 0.6286)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=8 → 10 (Score: 0.6285)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=8 → 9 (Score: 0.5190)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=8 (Unchanged, Score: 0.4090)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=8 (Unchanged, Score: 0.4869)
#   - base_model.model.model.layers.9.mlp.up_proj: r=8 (Unchanged, Score: 0.4843)
#   - base_model.model.model.layers.9.mlp.down_proj: r=8 (Unchanged, Score: 0.4845)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=8 (Unchanged, Score: 0.4004)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=8 (Unchanged, Score: 0.4319)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=8 → 7 (Score: 0.3141)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=8 → 7 (Score: 0.3205)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=8 (Unchanged, Score: 0.4749)
#   - base_model.model.model.layers.10.mlp.up_proj: r=8 (Unchanged, Score: 0.4195)
#   - base_model.model.model.layers.10.mlp.down_proj: r=8 (Unchanged, Score: 0.4195)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=8 → 7 (Score: 0.3588)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=8 → 9 (Score: 0.6068)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=8 (Unchanged, Score: 0.4354)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=8 → 7 (Score: 0.2743)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=8 (Unchanged, Score: 0.4864)
#   - base_model.model.model.layers.11.mlp.up_proj: r=8 → 9 (Score: 0.5226)
#   - base_model.model.model.layers.11.mlp.down_proj: r=8 → 9 (Score: 0.5226)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=8 (Unchanged, Score: 0.4014)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=8 → 10 (Score: 0.6338)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=8 → 7 (Score: 0.3818)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=8 → 7 (Score: 0.3557)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=8 → 7 (Score: 0.3912)
#   - base_model.model.model.layers.12.mlp.up_proj: r=8 (Unchanged, Score: 0.3980)
#   - base_model.model.model.layers.12.mlp.down_proj: r=8 (Unchanged, Score: 0.3980)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=8 → 7 (Score: 0.3004)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=8 (Unchanged, Score: 0.4851)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=8 → 7 (Score: 0.2856)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=8 → 6 (Score: 0.2465)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=8 (Unchanged, Score: 0.4497)
#   - base_model.model.model.layers.13.mlp.up_proj: r=8 (Unchanged, Score: 0.4621)
#   - base_model.model.model.layers.13.mlp.down_proj: r=8 (Unchanged, Score: 0.4622)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=8 → 7 (Score: 0.3654)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=8 → 9 (Score: 0.5579)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=8 → 7 (Score: 0.3555)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=8 → 7 (Score: 0.3526)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=8 → 14 (Score: 0.9713)
#   - base_model.model.model.layers.14.mlp.up_proj: r=8 → 10 (Score: 0.6353)
#   - base_model.model.model.layers.14.mlp.down_proj: r=8 → 10 (Score: 0.6350)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=8 → 6 (Score: 0.2289)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=8 (Unchanged, Score: 0.4768)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=8 → 7 (Score: 0.3268)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=8 → 6 (Score: 0.1367)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=8 → 9 (Score: 0.5320)
#   - base_model.model.model.layers.15.mlp.up_proj: r=8 (Unchanged, Score: 0.4707)
#   - base_model.model.model.layers.15.mlp.down_proj: r=8 (Unchanged, Score: 0.4707)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=8 → 7 (Score: 0.3347)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=8 (Unchanged, Score: 0.4478)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=8 → 7 (Score: 0.3852)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=8 → 6 (Score: 0.1573)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=8 → 13 (Score: 0.8645)
#   - base_model.model.model.layers.16.mlp.up_proj: r=8 → 10 (Score: 0.6692)
#   - base_model.model.model.layers.16.mlp.down_proj: r=8 → 10 (Score: 0.6691)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=8 → 6 (Score: 0.1686)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=8 (Unchanged, Score: 0.4147)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=8 → 6 (Score: 0.2112)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=8 → 6 (Score: 0.1341)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=8 (Unchanged, Score: 0.4915)
#   - base_model.model.model.layers.17.mlp.up_proj: r=8 (Unchanged, Score: 0.4410)
#   - base_model.model.model.layers.17.mlp.down_proj: r=8 (Unchanged, Score: 0.4412)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=8 → 6 (Score: 0.1611)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=8 → 10 (Score: 0.6673)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=8 → 7 (Score: 0.3442)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=8 → 6 (Score: 0.1391)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=8 → 7 (Score: 0.3667)
#   - base_model.model.model.layers.18.mlp.up_proj: r=8 (Unchanged, Score: 0.4316)
#   - base_model.model.model.layers.18.mlp.down_proj: r=8 (Unchanged, Score: 0.4314)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=8 → 6 (Score: 0.1390)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=8 (Unchanged, Score: 0.4571)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=8 → 7 (Score: 0.3687)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=8 → 5 (Score: 0.0689)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=8 → 7 (Score: 0.2955)
#   - base_model.model.model.layers.19.mlp.up_proj: r=8 → 6 (Score: 0.2540)
#   - base_model.model.model.layers.19.mlp.down_proj: r=8 → 6 (Score: 0.2540)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=8 → 6 (Score: 0.1534)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=8 → 9 (Score: 0.5797)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=8 → 7 (Score: 0.3700)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=8 → 5 (Score: 0.0947)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=8 → 11 (Score: 0.7715)
#   - base_model.model.model.layers.20.mlp.up_proj: r=8 (Unchanged, Score: 0.4931)
#   - base_model.model.model.layers.20.mlp.down_proj: r=8 (Unchanged, Score: 0.4930)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=8 → 6 (Score: 0.2015)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=8 → 15 (Score: 1.0000)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=8 (Unchanged, Score: 0.4204)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=8 → 5 (Score: 0.0426)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=8 → 5 (Score: 0.0060)
#   - base_model.model.model.layers.21.mlp.up_proj: r=8 → 5 (Score: 0.0001)
#   - base_model.model.model.layers.21.mlp.down_proj: r=8 → 5 (Score: 0.0000)
# ✅ AdaptiveLoRA: Rank setup for Epoch 1 complete.
#     <div>
#
#       <progress value='1560' max='1560' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1560/1560 1:27:15, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.651600</td>
#       <td>0.529742</td>
#       <td>0.718412</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.286000</td>
#       <td>0.491324</td>
#       <td>0.794224</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.273100</td>
#       <td>0.664771</td>
#       <td>0.797834</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.110600</td>
#       <td>1.115778</td>
#       <td>0.805054</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.026900</td>
#       <td>1.132245</td>
#       <td>0.819495</td>
#     </tr>
#   </tbody>
# </table><p>
# 📄 Epoch 1: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
#
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 2 ---
# Computing BI importance scores (pre-training)...
# Computing Importance:   0%|          | 0/35 [00:00<?, ?it/s]
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=6 → 7 (Score: 0.1556)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=7 (Unchanged, Score: 0.2391)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=7 (Unchanged, Score: 0.1838)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=10 → 9 (Score: 0.4466)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=8 (Unchanged, Score: 0.2734)
#   - base_model.model.model.layers.0.mlp.up_proj: r=7 → 8 (Score: 0.2821)
#   - base_model.model.model.layers.0.mlp.down_proj: r=7 → 8 (Score: 0.2821)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=7 → 8 (Score: 0.2909)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=12 → 11 (Score: 0.5692)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=8 (Unchanged, Score: 0.3652)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=8 (Unchanged, Score: 0.3635)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=8 (Unchanged, Score: 0.3315)
#   - base_model.model.model.layers.1.mlp.up_proj: r=8 (Unchanged, Score: 0.3146)
#   - base_model.model.model.layers.1.mlp.down_proj: r=8 (Unchanged, Score: 0.3147)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=8 (Unchanged, Score: 0.3367)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=13 → 11 (Score: 0.6197)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=8 (Unchanged, Score: 0.3489)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=8 (Unchanged, Score: 0.3594)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=8 → 9 (Score: 0.3778)
#   - base_model.model.model.layers.2.mlp.up_proj: r=8 → 9 (Score: 0.3679)
#   - base_model.model.model.layers.2.mlp.down_proj: r=8 → 9 (Score: 0.3679)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=13 → 11 (Score: 0.6048)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=8 (Unchanged, Score: 0.3289)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=7 → 8 (Score: 0.2633)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=7 (Unchanged, Score: 0.2486)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=8 (Unchanged, Score: 0.3551)
#   - base_model.model.model.layers.3.mlp.up_proj: r=8 (Unchanged, Score: 0.3480)
#   - base_model.model.model.layers.3.mlp.down_proj: r=8 (Unchanged, Score: 0.3479)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=11 (Unchanged, Score: 0.5670)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=8 (Unchanged, Score: 0.2839)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=7 (Unchanged, Score: 0.2407)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=7 (Unchanged, Score: 0.2445)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=8 → 9 (Score: 0.3974)
#   - base_model.model.model.layers.4.mlp.up_proj: r=8 → 9 (Score: 0.3841)
#   - base_model.model.model.layers.4.mlp.down_proj: r=8 → 9 (Score: 0.3842)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=11 (Unchanged, Score: 0.6009)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=8 (Unchanged, Score: 0.3132)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=7 → 8 (Score: 0.2792)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=7 (Unchanged, Score: 0.2518)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=8 → 9 (Score: 0.3969)
#   - base_model.model.model.layers.5.mlp.up_proj: r=8 → 9 (Score: 0.3915)
#   - base_model.model.model.layers.5.mlp.down_proj: r=8 → 9 (Score: 0.3915)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=13 (Unchanged, Score: 0.7400)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=8 → 9 (Score: 0.4403)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=8 → 9 (Score: 0.3725)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=7 → 9 (Score: 0.3835)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=8 → 9 (Score: 0.4428)
#   - base_model.model.model.layers.6.mlp.up_proj: r=8 → 9 (Score: 0.4531)
#   - base_model.model.model.layers.6.mlp.down_proj: r=8 → 9 (Score: 0.4531)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=10 → 12 (Score: 0.6650)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=9 (Unchanged, Score: 0.4600)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=8 → 9 (Score: 0.3883)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=7 → 8 (Score: 0.3448)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=11 → 13 (Score: 0.7225)
#   - base_model.model.model.layers.7.mlp.up_proj: r=10 (Unchanged, Score: 0.5519)
#   - base_model.model.model.layers.7.mlp.down_proj: r=10 (Unchanged, Score: 0.5521)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=10 → 12 (Score: 0.6646)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=8 → 10 (Score: 0.5272)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=7 → 9 (Score: 0.4486)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=7 → 8 (Score: 0.2937)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=8 → 10 (Score: 0.5191)
#   - base_model.model.model.layers.8.mlp.up_proj: r=8 → 9 (Score: 0.4551)
#   - base_model.model.model.layers.8.mlp.down_proj: r=8 → 9 (Score: 0.4551)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=10 → 11 (Score: 0.5700)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=10 → 9 (Score: 0.4476)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=9 (Unchanged, Score: 0.4527)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=8 → 9 (Score: 0.3657)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=8 → 10 (Score: 0.5099)
#   - base_model.model.model.layers.9.mlp.up_proj: r=8 → 9 (Score: 0.4596)
#   - base_model.model.model.layers.9.mlp.down_proj: r=8 → 9 (Score: 0.4595)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=8 → 10 (Score: 0.5369)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=8 → 11 (Score: 0.5668)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=7 → 9 (Score: 0.4427)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=7 → 8 (Score: 0.3607)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=8 → 12 (Score: 0.6701)
#   - base_model.model.model.layers.10.mlp.up_proj: r=8 → 10 (Score: 0.5567)
#   - base_model.model.model.layers.10.mlp.down_proj: r=8 → 11 (Score: 0.5567)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=7 → 11 (Score: 0.6103)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=9 → 17 (Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=8 → 12 (Score: 0.6755)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=7 → 9 (Score: 0.4333)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=8 → 9 (Score: 0.4204)
#   - base_model.model.model.layers.11.mlp.up_proj: r=9 → 8 (Score: 0.3603)
#   - base_model.model.model.layers.11.mlp.down_proj: r=9 → 8 (Score: 0.3602)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=8 (Unchanged, Score: 0.2563)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=10 → 16 (Score: 0.9540)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=7 → 9 (Score: 0.4297)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=7 (Unchanged, Score: 0.2170)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=7 (Unchanged, Score: 0.2069)
#   - base_model.model.model.layers.12.mlp.up_proj: r=8 → 7 (Score: 0.2192)
#   - base_model.model.model.layers.12.mlp.down_proj: r=8 → 7 (Score: 0.2191)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=7 → 6 (Score: 0.1086)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=8 → 7 (Score: 0.2470)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=7 (Unchanged, Score: 0.2265)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=6 → 7 (Score: 0.1685)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=8 → 7 (Score: 0.1831)
#   - base_model.model.model.layers.13.mlp.up_proj: r=8 → 7 (Score: 0.1563)
#   - base_model.model.model.layers.13.mlp.down_proj: r=8 → 7 (Score: 0.1562)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=7 → 6 (Score: 0.0780)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=9 → 6 (Score: 0.1135)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=7 (Unchanged, Score: 0.1413)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=7 → 6 (Score: 0.0915)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=14 → 7 (Score: 0.1658)
#   - base_model.model.model.layers.14.mlp.up_proj: r=10 → 6 (Score: 0.1094)
#   - base_model.model.model.layers.14.mlp.down_proj: r=10 → 6 (Score: 0.1093)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=6 (Unchanged, Score: 0.0600)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=8 → 7 (Score: 0.1962)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=7 (Unchanged, Score: 0.1297)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=6 (Unchanged, Score: 0.0574)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=9 → 7 (Score: 0.1848)
#   - base_model.model.model.layers.15.mlp.up_proj: r=8 → 7 (Score: 0.1420)
#   - base_model.model.model.layers.15.mlp.down_proj: r=8 → 7 (Score: 0.1420)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=7 → 6 (Score: 0.1201)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=8 → 7 (Score: 0.1737)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=7 (Unchanged, Score: 0.1610)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=6 → 7 (Score: 0.1240)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=13 → 6 (Score: 0.0957)
#   - base_model.model.model.layers.16.mlp.up_proj: r=10 → 6 (Score: 0.0819)
#   - base_model.model.model.layers.16.mlp.down_proj: r=10 → 6 (Score: 0.0819)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=6 (Unchanged, Score: 0.0330)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=8 → 6 (Score: 0.1200)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=6 (Unchanged, Score: 0.0945)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=6 (Unchanged, Score: 0.0627)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=8 → 6 (Score: 0.0871)
#   - base_model.model.model.layers.17.mlp.up_proj: r=8 → 6 (Score: 0.0715)
#   - base_model.model.model.layers.17.mlp.down_proj: r=8 → 6 (Score: 0.0716)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=6 (Unchanged, Score: 0.0326)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=10 → 6 (Score: 0.0995)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=7 → 6 (Score: 0.0846)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=6 (Unchanged, Score: 0.0125)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=7 (Unchanged, Score: 0.1548)
#   - base_model.model.model.layers.18.mlp.up_proj: r=8 → 6 (Score: 0.0989)
#   - base_model.model.model.layers.18.mlp.down_proj: r=8 → 6 (Score: 0.0990)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=6 (Unchanged, Score: 0.0556)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=8 → 6 (Score: 0.1159)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=7 → 6 (Score: 0.0976)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=5 → 6 (Score: 0.0446)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=7 (Unchanged, Score: 0.1434)
#   - base_model.model.model.layers.19.mlp.up_proj: r=6 → 7 (Score: 0.1511)
#   - base_model.model.model.layers.19.mlp.down_proj: r=6 → 7 (Score: 0.1511)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=6 (Unchanged, Score: 0.0725)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=9 → 6 (Score: 0.0928)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=7 → 6 (Score: 0.0641)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=5 → 6 (Score: 0.0184)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=11 → 7 (Score: 0.1291)
#   - base_model.model.model.layers.20.mlp.up_proj: r=8 → 6 (Score: 0.1117)
#   - base_model.model.model.layers.20.mlp.down_proj: r=8 → 6 (Score: 0.1116)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=6 (Unchanged, Score: 0.0133)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=15 → 7 (Score: 0.1323)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=8 → 6 (Score: 0.0924)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=5 → 6 (Score: 0.0000)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=5 → 7 (Score: 0.1236)
#   - base_model.model.model.layers.21.mlp.up_proj: r=5 → 6 (Score: 0.1127)
#   - base_model.model.model.layers.21.mlp.down_proj: r=5 → 6 (Score: 0.1128)
# ✅ AdaptiveLoRA: Rank setup for Epoch 2 complete.
#
# 📄 Epoch 2: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
#
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 3 ---
# Computing BI importance scores (pre-training)...
# Computing Importance:   0%|          | 0/35 [00:00<?, ?it/s]
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=7 (Unchanged, Score: 0.1870)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=7 → 8 (Score: 0.2846)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=7 (Unchanged, Score: 0.1988)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=9 → 10 (Score: 0.4911)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=8 (Unchanged, Score: 0.3004)
#   - base_model.model.model.layers.0.mlp.up_proj: r=8 (Unchanged, Score: 0.3067)
#   - base_model.model.model.layers.0.mlp.down_proj: r=8 (Unchanged, Score: 0.3065)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=8 (Unchanged, Score: 0.3258)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=11 (Unchanged, Score: 0.6091)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=8 → 9 (Score: 0.3965)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=8 → 9 (Score: 0.4045)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=8 (Unchanged, Score: 0.3483)
#   - base_model.model.model.layers.1.mlp.up_proj: r=8 (Unchanged, Score: 0.3330)
#   - base_model.model.model.layers.1.mlp.down_proj: r=8 (Unchanged, Score: 0.3331)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=8 → 9 (Score: 0.3910)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=11 → 12 (Score: 0.6937)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=8 → 9 (Score: 0.3867)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=8 → 9 (Score: 0.4795)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=9 → 8 (Score: 0.3797)
#   - base_model.model.model.layers.2.mlp.up_proj: r=9 (Unchanged, Score: 0.3806)
#   - base_model.model.model.layers.2.mlp.down_proj: r=9 (Unchanged, Score: 0.3805)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=11 → 12 (Score: 0.6966)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=8 (Unchanged, Score: 0.3544)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=8 (Unchanged, Score: 0.2713)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=7 (Unchanged, Score: 0.2475)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=8 (Unchanged, Score: 0.3656)
#   - base_model.model.model.layers.3.mlp.up_proj: r=8 (Unchanged, Score: 0.3585)
#   - base_model.model.model.layers.3.mlp.down_proj: r=8 (Unchanged, Score: 0.3584)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=11 (Unchanged, Score: 0.6067)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=8 (Unchanged, Score: 0.3214)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=7 (Unchanged, Score: 0.2487)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=7 (Unchanged, Score: 0.2617)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=9 → 8 (Score: 0.3789)
#   - base_model.model.model.layers.4.mlp.up_proj: r=9 → 8 (Score: 0.3604)
#   - base_model.model.model.layers.4.mlp.down_proj: r=9 → 8 (Score: 0.3604)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=11 → 12 (Score: 0.6594)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=8 (Unchanged, Score: 0.3490)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=8 (Unchanged, Score: 0.2952)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=7 → 8 (Score: 0.2787)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=9 (Unchanged, Score: 0.3983)
#   - base_model.model.model.layers.5.mlp.up_proj: r=9 (Unchanged, Score: 0.4004)
#   - base_model.model.model.layers.5.mlp.down_proj: r=9 (Unchanged, Score: 0.4002)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=13 → 14 (Score: 0.8459)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=9 (Unchanged, Score: 0.4606)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=9 (Unchanged, Score: 0.4129)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=9 (Unchanged, Score: 0.3933)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=9 (Unchanged, Score: 0.4508)
#   - base_model.model.model.layers.6.mlp.up_proj: r=9 (Unchanged, Score: 0.4607)
#   - base_model.model.model.layers.6.mlp.down_proj: r=9 (Unchanged, Score: 0.4607)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=12 (Unchanged, Score: 0.7023)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=9 → 10 (Score: 0.5202)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=9 (Unchanged, Score: 0.4439)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=8 (Unchanged, Score: 0.3648)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=13 (Unchanged, Score: 0.7724)
#   - base_model.model.model.layers.7.mlp.up_proj: r=10 → 11 (Score: 0.5876)
#   - base_model.model.model.layers.7.mlp.down_proj: r=10 → 11 (Score: 0.5879)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=12 (Unchanged, Score: 0.6993)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=10 (Unchanged, Score: 0.5694)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=9 → 10 (Score: 0.5015)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=8 (Unchanged, Score: 0.3231)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=10 (Unchanged, Score: 0.5462)
#   - base_model.model.model.layers.8.mlp.up_proj: r=9 → 10 (Score: 0.4958)
#   - base_model.model.model.layers.8.mlp.down_proj: r=9 → 10 (Score: 0.4958)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=11 (Unchanged, Score: 0.5759)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=9 (Unchanged, Score: 0.4704)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=9 (Unchanged, Score: 0.4594)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=9 (Unchanged, Score: 0.3922)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=10 (Unchanged, Score: 0.5383)
#   - base_model.model.model.layers.9.mlp.up_proj: r=9 → 10 (Score: 0.5184)
#   - base_model.model.model.layers.9.mlp.down_proj: r=9 → 10 (Score: 0.5186)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=10 (Unchanged, Score: 0.5473)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=11 (Unchanged, Score: 0.5796)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=9 (Unchanged, Score: 0.4486)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=8 (Unchanged, Score: 0.3685)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=12 (Unchanged, Score: 0.7080)
#   - base_model.model.model.layers.10.mlp.up_proj: r=10 → 11 (Score: 0.6071)
#   - base_model.model.model.layers.10.mlp.down_proj: r=11 (Unchanged, Score: 0.6073)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=11 (Unchanged, Score: 0.6058)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=17 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=12 (Unchanged, Score: 0.7101)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=9 (Unchanged, Score: 0.4484)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=9 (Unchanged, Score: 0.4015)
#   - base_model.model.model.layers.11.mlp.up_proj: r=8 (Unchanged, Score: 0.3320)
#   - base_model.model.model.layers.11.mlp.down_proj: r=8 (Unchanged, Score: 0.3318)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=8 → 7 (Score: 0.2048)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=16 (Unchanged, Score: 0.9574)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=9 (Unchanged, Score: 0.3970)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=7 (Unchanged, Score: 0.1774)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=7 (Unchanged, Score: 0.1773)
#   - base_model.model.model.layers.12.mlp.up_proj: r=7 (Unchanged, Score: 0.2000)
#   - base_model.model.model.layers.12.mlp.down_proj: r=7 (Unchanged, Score: 0.1999)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=6 (Unchanged, Score: 0.1093)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=7 → 8 (Score: 0.2795)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=7 (Unchanged, Score: 0.2270)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=7 (Unchanged, Score: 0.1952)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=7 (Unchanged, Score: 0.1599)
#   - base_model.model.model.layers.13.mlp.up_proj: r=7 → 6 (Score: 0.1094)
#   - base_model.model.model.layers.13.mlp.down_proj: r=7 → 6 (Score: 0.1095)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=6 (Unchanged, Score: 0.0697)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=6 (Unchanged, Score: 0.0947)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=7 → 6 (Score: 0.1141)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=6 (Unchanged, Score: 0.0820)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=7 → 6 (Score: 0.1257)
#   - base_model.model.model.layers.14.mlp.up_proj: r=6 (Unchanged, Score: 0.1083)
#   - base_model.model.model.layers.14.mlp.down_proj: r=6 (Unchanged, Score: 0.1083)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=6 (Unchanged, Score: 0.0606)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=7 (Unchanged, Score: 0.1523)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=7 → 6 (Score: 0.0831)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=6 (Unchanged, Score: 0.0451)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=7 → 6 (Score: 0.1322)
#   - base_model.model.model.layers.15.mlp.up_proj: r=7 → 6 (Score: 0.0978)
#   - base_model.model.model.layers.15.mlp.down_proj: r=7 → 6 (Score: 0.0979)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=6 (Unchanged, Score: 0.0344)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=7 (Unchanged, Score: 0.1647)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=7 → 6 (Score: 0.1328)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=7 → 6 (Score: 0.1070)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=6 (Unchanged, Score: 0.0616)
#   - base_model.model.model.layers.16.mlp.up_proj: r=6 (Unchanged, Score: 0.0434)
#   - base_model.model.model.layers.16.mlp.down_proj: r=6 (Unchanged, Score: 0.0434)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=6 (Unchanged, Score: 0.0156)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=6 (Unchanged, Score: 0.0746)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=6 (Unchanged, Score: 0.0524)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=6 (Unchanged, Score: 0.0305)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=6 (Unchanged, Score: 0.0442)
#   - base_model.model.model.layers.17.mlp.up_proj: r=6 (Unchanged, Score: 0.0375)
#   - base_model.model.model.layers.17.mlp.down_proj: r=6 (Unchanged, Score: 0.0375)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=6 (Unchanged, Score: 0.0091)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=6 (Unchanged, Score: 0.0592)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=6 (Unchanged, Score: 0.0435)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=6 (Unchanged, Score: 0.0009)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=7 → 6 (Score: 0.0612)
#   - base_model.model.model.layers.18.mlp.up_proj: r=6 (Unchanged, Score: 0.0449)
#   - base_model.model.model.layers.18.mlp.down_proj: r=6 (Unchanged, Score: 0.0449)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=6 (Unchanged, Score: 0.0268)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=6 (Unchanged, Score: 0.0584)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=6 (Unchanged, Score: 0.0386)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=6 (Unchanged, Score: 0.0006)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=7 → 6 (Score: 0.0266)
#   - base_model.model.model.layers.19.mlp.up_proj: r=7 → 6 (Score: 0.0215)
#   - base_model.model.model.layers.19.mlp.down_proj: r=7 → 6 (Score: 0.0214)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=6 (Unchanged, Score: 0.0136)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=6 (Unchanged, Score: 0.0574)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=6 (Unchanged, Score: 0.0389)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=6 (Unchanged, Score: 0.0055)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=7 → 6 (Score: 0.0940)
#   - base_model.model.model.layers.20.mlp.up_proj: r=6 (Unchanged, Score: 0.0680)
#   - base_model.model.model.layers.20.mlp.down_proj: r=6 (Unchanged, Score: 0.0680)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=6 (Unchanged, Score: 0.0122)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=7 → 6 (Score: 0.1005)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=6 (Unchanged, Score: 0.0610)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=6 (Unchanged, Score: 0.0000)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=7 → 6 (Score: 0.0679)
#   - base_model.model.model.layers.21.mlp.up_proj: r=6 (Unchanged, Score: 0.0636)
#   - base_model.model.model.layers.21.mlp.down_proj: r=6 (Unchanged, Score: 0.0636)
# ✅ AdaptiveLoRA: Rank setup for Epoch 3 complete.
#
# 📄 Epoch 3: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
#
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 4 ---
# Computing BI importance scores (pre-training)...
# Computing Importance:   0%|          | 0/35 [00:00<?, ?it/s]
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=7 (Unchanged, Score: 0.1963)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=8 → 7 (Score: 0.2858)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=7 (Unchanged, Score: 0.2111)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=10 (Unchanged, Score: 0.5244)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=8 (Unchanged, Score: 0.3273)
#   - base_model.model.model.layers.0.mlp.up_proj: r=8 (Unchanged, Score: 0.3326)
#   - base_model.model.model.layers.0.mlp.down_proj: r=8 (Unchanged, Score: 0.3327)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=8 (Unchanged, Score: 0.3524)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=11 (Unchanged, Score: 0.6536)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=9 (Unchanged, Score: 0.4479)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=9 (Unchanged, Score: 0.4408)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=8 (Unchanged, Score: 0.3889)
#   - base_model.model.model.layers.1.mlp.up_proj: r=8 (Unchanged, Score: 0.3719)
#   - base_model.model.model.layers.1.mlp.down_proj: r=8 (Unchanged, Score: 0.3720)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=9 (Unchanged, Score: 0.4059)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=12 (Unchanged, Score: 0.7410)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=9 (Unchanged, Score: 0.4252)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=9 (Unchanged, Score: 0.4749)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=8 → 9 (Score: 0.4382)
#   - base_model.model.model.layers.2.mlp.up_proj: r=9 (Unchanged, Score: 0.4321)
#   - base_model.model.model.layers.2.mlp.down_proj: r=9 (Unchanged, Score: 0.4321)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=12 (Unchanged, Score: 0.7112)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=8 (Unchanged, Score: 0.3835)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=8 (Unchanged, Score: 0.3166)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=7 (Unchanged, Score: 0.2893)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=8 → 9 (Score: 0.4402)
#   - base_model.model.model.layers.3.mlp.up_proj: r=8 → 9 (Score: 0.4369)
#   - base_model.model.model.layers.3.mlp.down_proj: r=8 → 9 (Score: 0.4369)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=11 → 12 (Score: 0.6933)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=8 (Unchanged, Score: 0.3808)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=7 → 8 (Score: 0.3040)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=7 → 8 (Score: 0.3092)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=8 → 9 (Score: 0.4052)
#   - base_model.model.model.layers.4.mlp.up_proj: r=8 (Unchanged, Score: 0.3943)
#   - base_model.model.model.layers.4.mlp.down_proj: r=8 (Unchanged, Score: 0.3943)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=12 (Unchanged, Score: 0.6734)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=8 (Unchanged, Score: 0.3420)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=8 (Unchanged, Score: 0.2937)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=8 → 7 (Score: 0.2842)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=9 (Unchanged, Score: 0.4379)
#   - base_model.model.model.layers.5.mlp.up_proj: r=9 (Unchanged, Score: 0.4452)
#   - base_model.model.model.layers.5.mlp.down_proj: r=9 (Unchanged, Score: 0.4453)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=14 (Unchanged, Score: 0.8600)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=9 (Unchanged, Score: 0.4512)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=9 (Unchanged, Score: 0.4141)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=9 (Unchanged, Score: 0.4306)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=9 (Unchanged, Score: 0.4641)
#   - base_model.model.model.layers.6.mlp.up_proj: r=9 (Unchanged, Score: 0.4748)
#   - base_model.model.model.layers.6.mlp.down_proj: r=9 (Unchanged, Score: 0.4750)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=12 → 13 (Score: 0.7496)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=10 (Unchanged, Score: 0.5069)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=9 (Unchanged, Score: 0.4328)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=8 (Unchanged, Score: 0.3720)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=13 (Unchanged, Score: 0.7913)
#   - base_model.model.model.layers.7.mlp.up_proj: r=11 (Unchanged, Score: 0.6289)
#   - base_model.model.model.layers.7.mlp.down_proj: r=11 (Unchanged, Score: 0.6290)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=12 → 13 (Score: 0.7697)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=10 → 11 (Score: 0.6122)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=10 (Unchanged, Score: 0.5172)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=8 (Unchanged, Score: 0.3679)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=10 (Unchanged, Score: 0.5448)
#   - base_model.model.model.layers.8.mlp.up_proj: r=10 → 9 (Score: 0.4995)
#   - base_model.model.model.layers.8.mlp.down_proj: r=10 → 9 (Score: 0.4994)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=11 (Unchanged, Score: 0.6173)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=9 (Unchanged, Score: 0.4822)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=9 (Unchanged, Score: 0.4696)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=9 (Unchanged, Score: 0.4092)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=10 (Unchanged, Score: 0.5663)
#   - base_model.model.model.layers.9.mlp.up_proj: r=10 (Unchanged, Score: 0.5515)
#   - base_model.model.model.layers.9.mlp.down_proj: r=10 (Unchanged, Score: 0.5513)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=10 (Unchanged, Score: 0.5860)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=11 (Unchanged, Score: 0.5932)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=9 (Unchanged, Score: 0.4719)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=8 (Unchanged, Score: 0.3916)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=12 → 13 (Score: 0.7610)
#   - base_model.model.model.layers.10.mlp.up_proj: r=11 (Unchanged, Score: 0.6327)
#   - base_model.model.model.layers.10.mlp.down_proj: r=11 (Unchanged, Score: 0.6327)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=11 (Unchanged, Score: 0.6210)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=17 (Unchanged, Score: 1.0000)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=12 (Unchanged, Score: 0.7064)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=9 (Unchanged, Score: 0.4602)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=9 (Unchanged, Score: 0.4048)
#   - base_model.model.model.layers.11.mlp.up_proj: r=8 (Unchanged, Score: 0.3524)
#   - base_model.model.model.layers.11.mlp.down_proj: r=8 (Unchanged, Score: 0.3524)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=7 (Unchanged, Score: 0.2277)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=16 → 15 (Score: 0.9322)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=9 (Unchanged, Score: 0.4055)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=7 (Unchanged, Score: 0.1875)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=7 (Unchanged, Score: 0.1824)
#   - base_model.model.model.layers.12.mlp.up_proj: r=7 (Unchanged, Score: 0.2040)
#   - base_model.model.model.layers.12.mlp.down_proj: r=7 (Unchanged, Score: 0.2039)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=6 (Unchanged, Score: 0.1364)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=8 (Unchanged, Score: 0.2946)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=7 (Unchanged, Score: 0.2418)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=7 (Unchanged, Score: 0.2092)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=7 → 6 (Score: 0.1507)
#   - base_model.model.model.layers.13.mlp.up_proj: r=6 (Unchanged, Score: 0.1088)
#   - base_model.model.model.layers.13.mlp.down_proj: r=6 (Unchanged, Score: 0.1089)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=6 (Unchanged, Score: 0.0697)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=6 (Unchanged, Score: 0.0986)
# ...
#   - base_model.model.model.layers.17.mlp.gate_proj: r=6 (Unchanged, Score: 0.0322)
#   - base_model.model.model.layers.17.mlp.up_proj: r=6 (Unchanged, Score: 0.0289)
#   - base_model.model.model.layers.17.mlp.down_proj: r=6 (Unchanged, Score: 0.0288)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=6 → 5 (Score: 0.0098)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=6 (Unchanged, Score: 0.0445)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=6 (Unchanged, Score: 0.0303)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=6 → 5 (Score: 0.0044)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=6 (Unchanged, Score: 0.0420)
#   - base_model.model.model.layers.18.mlp.up_proj: r=6 (Unchanged, Score: 0.0267)
#   - base_model.model.model.layers.18.mlp.down_proj: r=6 (Unchanged, Score: 0.0267)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=6 (Unchanged, Score: 0.0189)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=6 (Unchanged, Score: 0.0383)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=6 (Unchanged, Score: 0.0265)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=6 → 5 (Score: 0.0044)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=6 (Unchanged, Score: 0.0280)
#   - base_model.model.model.layers.19.mlp.up_proj: r=6 (Unchanged, Score: 0.0156)
#   - base_model.model.model.layers.19.mlp.down_proj: r=6 (Unchanged, Score: 0.0156)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=6 (Unchanged, Score: 0.0168)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=6 (Unchanged, Score: 0.0303)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=6 (Unchanged, Score: 0.0237)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=6 → 5 (Score: 0.0061)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=6 (Unchanged, Score: 0.0476)
#   - base_model.model.model.layers.20.mlp.up_proj: r=6 (Unchanged, Score: 0.0353)
#   - base_model.model.model.layers.20.mlp.down_proj: r=6 (Unchanged, Score: 0.0354)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=6 (Unchanged, Score: 0.0195)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=6 (Unchanged, Score: 0.0653)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=6 (Unchanged, Score: 0.0380)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=6 → 5 (Score: 0.0000)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=6 (Unchanged, Score: 0.0302)
#   - base_model.model.model.layers.21.mlp.up_proj: r=6 (Unchanged, Score: 0.0290)
#   - base_model.model.model.layers.21.mlp.down_proj: r=6 (Unchanged, Score: 0.0290)
# ✅ AdaptiveLoRA: Rank setup for Epoch 4 complete.
#
# 📄 Epoch 4: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
#
#
# --- AdaptiveLoRA: Preparing ranks for Epoch 5 ---
# Computing BI importance scores (pre-training)...
# Computing Importance:   0%|          | 0/35 [00:00<?, ?it/s]
# Allocating new ranks based on BI scores...
# Applying new ranks to LoRA modules for this epoch...
#   - base_model.model.model.layers.0.self_attn.q_proj: r=7 (Unchanged, Score: 0.2220)
#   - base_model.model.model.layers.0.self_attn.k_proj: r=7 → 8 (Score: 0.3345)
#   - base_model.model.model.layers.0.self_attn.v_proj: r=7 (Unchanged, Score: 0.2603)
#   - base_model.model.model.layers.0.self_attn.o_proj: r=10 → 11 (Score: 0.6170)
#   - base_model.model.model.layers.0.mlp.gate_proj: r=8 (Unchanged, Score: 0.3713)
#   - base_model.model.model.layers.0.mlp.up_proj: r=8 (Unchanged, Score: 0.3773)
#   - base_model.model.model.layers.0.mlp.down_proj: r=8 (Unchanged, Score: 0.3773)
#   - base_model.model.model.layers.1.self_attn.q_proj: r=8 (Unchanged, Score: 0.4131)
#   - base_model.model.model.layers.1.self_attn.k_proj: r=11 → 12 (Score: 0.7575)
#   - base_model.model.model.layers.1.self_attn.v_proj: r=9 (Unchanged, Score: 0.5081)
#   - base_model.model.model.layers.1.self_attn.o_proj: r=9 (Unchanged, Score: 0.5042)
#   - base_model.model.model.layers.1.mlp.gate_proj: r=8 → 9 (Score: 0.5072)
#   - base_model.model.model.layers.1.mlp.up_proj: r=8 → 9 (Score: 0.4877)
#   - base_model.model.model.layers.1.mlp.down_proj: r=8 → 9 (Score: 0.4875)
#   - base_model.model.model.layers.2.self_attn.q_proj: r=9 (Unchanged, Score: 0.4607)
#   - base_model.model.model.layers.2.self_attn.k_proj: r=12 → 14 (Score: 0.8453)
#   - base_model.model.model.layers.2.self_attn.v_proj: r=9 (Unchanged, Score: 0.4882)
#   - base_model.model.model.layers.2.self_attn.o_proj: r=9 → 10 (Score: 0.5738)
#   - base_model.model.model.layers.2.mlp.gate_proj: r=9 (Unchanged, Score: 0.5059)
#   - base_model.model.model.layers.2.mlp.up_proj: r=9 (Unchanged, Score: 0.5007)
#   - base_model.model.model.layers.2.mlp.down_proj: r=9 (Unchanged, Score: 0.5005)
#   - base_model.model.model.layers.3.self_attn.q_proj: r=12 → 13 (Score: 0.7975)
#   - base_model.model.model.layers.3.self_attn.k_proj: r=8 → 9 (Score: 0.4618)
#   - base_model.model.model.layers.3.self_attn.v_proj: r=8 (Unchanged, Score: 0.3741)
#   - base_model.model.model.layers.3.self_attn.o_proj: r=7 → 8 (Score: 0.3365)
#   - base_model.model.model.layers.3.mlp.gate_proj: r=9 (Unchanged, Score: 0.4786)
#   - base_model.model.model.layers.3.mlp.up_proj: r=9 (Unchanged, Score: 0.4820)
#   - base_model.model.model.layers.3.mlp.down_proj: r=9 (Unchanged, Score: 0.4819)
#   - base_model.model.model.layers.4.self_attn.q_proj: r=12 → 13 (Score: 0.8045)
#   - base_model.model.model.layers.4.self_attn.k_proj: r=8 → 9 (Score: 0.4308)
#   - base_model.model.model.layers.4.self_attn.v_proj: r=8 (Unchanged, Score: 0.3397)
#   - base_model.model.model.layers.4.self_attn.o_proj: r=8 (Unchanged, Score: 0.3495)
#   - base_model.model.model.layers.4.mlp.gate_proj: r=9 (Unchanged, Score: 0.4524)
#   - base_model.model.model.layers.4.mlp.up_proj: r=8 → 9 (Score: 0.4506)
#   - base_model.model.model.layers.4.mlp.down_proj: r=8 → 9 (Score: 0.4506)
#   - base_model.model.model.layers.5.self_attn.q_proj: r=12 (Unchanged, Score: 0.7181)
#   - base_model.model.model.layers.5.self_attn.k_proj: r=8 (Unchanged, Score: 0.3665)
#   - base_model.model.model.layers.5.self_attn.v_proj: r=8 (Unchanged, Score: 0.3160)
#   - base_model.model.model.layers.5.self_attn.o_proj: r=7 → 8 (Score: 0.3214)
#   - base_model.model.model.layers.5.mlp.gate_proj: r=9 (Unchanged, Score: 0.4980)
#   - base_model.model.model.layers.5.mlp.up_proj: r=9 (Unchanged, Score: 0.5106)
#   - base_model.model.model.layers.5.mlp.down_proj: r=9 (Unchanged, Score: 0.5104)
#   - base_model.model.model.layers.6.self_attn.q_proj: r=14 → 15 (Score: 0.9227)
#   - base_model.model.model.layers.6.self_attn.k_proj: r=9 (Unchanged, Score: 0.4637)
#   - base_model.model.model.layers.6.self_attn.v_proj: r=9 → 8 (Score: 0.4171)
#   - base_model.model.model.layers.6.self_attn.o_proj: r=9 (Unchanged, Score: 0.4323)
#   - base_model.model.model.layers.6.mlp.gate_proj: r=9 (Unchanged, Score: 0.4940)
#   - base_model.model.model.layers.6.mlp.up_proj: r=9 (Unchanged, Score: 0.5048)
#   - base_model.model.model.layers.6.mlp.down_proj: r=9 (Unchanged, Score: 0.5050)
#   - base_model.model.model.layers.7.self_attn.q_proj: r=13 (Unchanged, Score: 0.7894)
#   - base_model.model.model.layers.7.self_attn.k_proj: r=10 (Unchanged, Score: 0.5300)
#   - base_model.model.model.layers.7.self_attn.v_proj: r=9 (Unchanged, Score: 0.4358)
#   - base_model.model.model.layers.7.self_attn.o_proj: r=8 (Unchanged, Score: 0.4067)
#   - base_model.model.model.layers.7.mlp.gate_proj: r=13 → 14 (Score: 0.8829)
#   - base_model.model.model.layers.7.mlp.up_proj: r=11 → 12 (Score: 0.7041)
#   - base_model.model.model.layers.7.mlp.down_proj: r=11 → 12 (Score: 0.7041)
#   - base_model.model.model.layers.8.self_attn.q_proj: r=13 (Unchanged, Score: 0.8383)
#   - base_model.model.model.layers.8.self_attn.k_proj: r=11 (Unchanged, Score: 0.6731)
#   - base_model.model.model.layers.8.self_attn.v_proj: r=10 (Unchanged, Score: 0.5495)
#   - base_model.model.model.layers.8.self_attn.o_proj: r=8 (Unchanged, Score: 0.4005)
#   - base_model.model.model.layers.8.mlp.gate_proj: r=10 (Unchanged, Score: 0.5847)
#   - base_model.model.model.layers.8.mlp.up_proj: r=9 → 10 (Score: 0.5376)
#   - base_model.model.model.layers.8.mlp.down_proj: r=9 → 10 (Score: 0.5376)
#   - base_model.model.model.layers.9.self_attn.q_proj: r=11 (Unchanged, Score: 0.6209)
#   - base_model.model.model.layers.9.self_attn.k_proj: r=9 (Unchanged, Score: 0.5040)
#   - base_model.model.model.layers.9.self_attn.v_proj: r=9 (Unchanged, Score: 0.4825)
#   - base_model.model.model.layers.9.self_attn.o_proj: r=9 (Unchanged, Score: 0.4298)
#   - base_model.model.model.layers.9.mlp.gate_proj: r=10 (Unchanged, Score: 0.5881)
#   - base_model.model.model.layers.9.mlp.up_proj: r=10 (Unchanged, Score: 0.5802)
#   - base_model.model.model.layers.9.mlp.down_proj: r=10 (Unchanged, Score: 0.5801)
#   - base_model.model.model.layers.10.self_attn.q_proj: r=10 → 11 (Score: 0.6234)
#   - base_model.model.model.layers.10.self_attn.k_proj: r=11 → 10 (Score: 0.5936)
#   - base_model.model.model.layers.10.self_attn.v_proj: r=9 (Unchanged, Score: 0.4861)
#   - base_model.model.model.layers.10.self_attn.o_proj: r=8 (Unchanged, Score: 0.4163)
#   - base_model.model.model.layers.10.mlp.gate_proj: r=13 → 14 (Score: 0.8398)
#   - base_model.model.model.layers.10.mlp.up_proj: r=11 → 12 (Score: 0.7018)
#   - base_model.model.model.layers.10.mlp.down_proj: r=11 → 12 (Score: 0.7019)
#   - base_model.model.model.layers.11.self_attn.q_proj: r=11 (Unchanged, Score: 0.6486)
#   - base_model.model.model.layers.11.self_attn.k_proj: r=17 → 16 (Score: 0.9974)
#   - base_model.model.model.layers.11.self_attn.v_proj: r=12 (Unchanged, Score: 0.7141)
#   - base_model.model.model.layers.11.self_attn.o_proj: r=9 (Unchanged, Score: 0.5103)
#   - base_model.model.model.layers.11.mlp.gate_proj: r=9 (Unchanged, Score: 0.4262)
#   - base_model.model.model.layers.11.mlp.up_proj: r=8 (Unchanged, Score: 0.3776)
#   - base_model.model.model.layers.11.mlp.down_proj: r=8 (Unchanged, Score: 0.3777)
#   - base_model.model.model.layers.12.self_attn.q_proj: r=7 (Unchanged, Score: 0.2565)
#   - base_model.model.model.layers.12.self_attn.k_proj: r=15 → 16 (Score: 1.0000)
#   - base_model.model.model.layers.12.self_attn.v_proj: r=9 (Unchanged, Score: 0.4256)
#   - base_model.model.model.layers.12.self_attn.o_proj: r=7 (Unchanged, Score: 0.2069)
#   - base_model.model.model.layers.12.mlp.gate_proj: r=7 (Unchanged, Score: 0.2045)
#   - base_model.model.model.layers.12.mlp.up_proj: r=7 (Unchanged, Score: 0.2228)
#   - base_model.model.model.layers.12.mlp.down_proj: r=7 (Unchanged, Score: 0.2227)
#   - base_model.model.model.layers.13.self_attn.q_proj: r=6 (Unchanged, Score: 0.1700)
#   - base_model.model.model.layers.13.self_attn.k_proj: r=8 (Unchanged, Score: 0.3177)
#   - base_model.model.model.layers.13.self_attn.v_proj: r=7 (Unchanged, Score: 0.2513)
#   - base_model.model.model.layers.13.self_attn.o_proj: r=7 (Unchanged, Score: 0.2069)
#   - base_model.model.model.layers.13.mlp.gate_proj: r=6 (Unchanged, Score: 0.1552)
#   - base_model.model.model.layers.13.mlp.up_proj: r=6 (Unchanged, Score: 0.1237)
#   - base_model.model.model.layers.13.mlp.down_proj: r=6 (Unchanged, Score: 0.1238)
#   - base_model.model.model.layers.14.self_attn.q_proj: r=6 (Unchanged, Score: 0.0725)
#   - base_model.model.model.layers.14.self_attn.k_proj: r=6 (Unchanged, Score: 0.1066)
#   - base_model.model.model.layers.14.self_attn.v_proj: r=6 (Unchanged, Score: 0.1642)
#   - base_model.model.model.layers.14.self_attn.o_proj: r=6 (Unchanged, Score: 0.1140)
#   - base_model.model.model.layers.14.mlp.gate_proj: r=6 (Unchanged, Score: 0.1299)
#   - base_model.model.model.layers.14.mlp.up_proj: r=6 (Unchanged, Score: 0.1014)
#   - base_model.model.model.layers.14.mlp.down_proj: r=6 (Unchanged, Score: 0.1014)
#   - base_model.model.model.layers.15.self_attn.q_proj: r=6 (Unchanged, Score: 0.0610)
#   - base_model.model.model.layers.15.self_attn.k_proj: r=6 (Unchanged, Score: 0.1089)
#   - base_model.model.model.layers.15.self_attn.v_proj: r=6 (Unchanged, Score: 0.0860)
#   - base_model.model.model.layers.15.self_attn.o_proj: r=6 (Unchanged, Score: 0.0592)
#   - base_model.model.model.layers.15.mlp.gate_proj: r=6 (Unchanged, Score: 0.1237)
#   - base_model.model.model.layers.15.mlp.up_proj: r=6 (Unchanged, Score: 0.1089)
#   - base_model.model.model.layers.15.mlp.down_proj: r=6 (Unchanged, Score: 0.1089)
#   - base_model.model.model.layers.16.self_attn.q_proj: r=6 (Unchanged, Score: 0.0522)
#   - base_model.model.model.layers.16.self_attn.k_proj: r=7 (Unchanged, Score: 0.2337)
#   - base_model.model.model.layers.16.self_attn.v_proj: r=6 (Unchanged, Score: 0.0917)
#   - base_model.model.model.layers.16.self_attn.o_proj: r=6 (Unchanged, Score: 0.0716)
#   - base_model.model.model.layers.16.mlp.gate_proj: r=6 (Unchanged, Score: 0.0430)
#   - base_model.model.model.layers.16.mlp.up_proj: r=6 (Unchanged, Score: 0.0336)
#   - base_model.model.model.layers.16.mlp.down_proj: r=6 (Unchanged, Score: 0.0336)
#   - base_model.model.model.layers.17.self_attn.q_proj: r=6 → 5 (Score: 0.0135)
#   - base_model.model.model.layers.17.self_attn.k_proj: r=6 → 5 (Score: 0.0250)
#   - base_model.model.model.layers.17.self_attn.v_proj: r=6 → 5 (Score: 0.0173)
#   - base_model.model.model.layers.17.self_attn.o_proj: r=6 → 5 (Score: 0.0110)
#   - base_model.model.model.layers.17.mlp.gate_proj: r=6 (Unchanged, Score: 0.0286)
#   - base_model.model.model.layers.17.mlp.up_proj: r=6 → 5 (Score: 0.0232)
#   - base_model.model.model.layers.17.mlp.down_proj: r=6 → 5 (Score: 0.0232)
#   - base_model.model.model.layers.18.self_attn.q_proj: r=5 (Unchanged, Score: 0.0062)
#   - base_model.model.model.layers.18.self_attn.k_proj: r=6 (Unchanged, Score: 0.0343)
#   - base_model.model.model.layers.18.self_attn.v_proj: r=6 → 5 (Score: 0.0213)
#   - base_model.model.model.layers.18.self_attn.o_proj: r=5 (Unchanged, Score: 0.0009)
#   - base_model.model.model.layers.18.mlp.gate_proj: r=6 → 5 (Score: 0.0256)
#   - base_model.model.model.layers.18.mlp.up_proj: r=6 → 5 (Score: 0.0224)
#   - base_model.model.model.layers.18.mlp.down_proj: r=6 → 5 (Score: 0.0223)
#   - base_model.model.model.layers.19.self_attn.q_proj: r=6 → 5 (Score: 0.0111)
#   - base_model.model.model.layers.19.self_attn.k_proj: r=6 (Unchanged, Score: 0.0338)
#   - base_model.model.model.layers.19.self_attn.v_proj: r=6 → 5 (Score: 0.0207)
#   - base_model.model.model.layers.19.self_attn.o_proj: r=5 (Unchanged, Score: 0.0001)
#   - base_model.model.model.layers.19.mlp.gate_proj: r=6 → 5 (Score: 0.0163)
#   - base_model.model.model.layers.19.mlp.up_proj: r=6 → 5 (Score: 0.0139)
#   - base_model.model.model.layers.19.mlp.down_proj: r=6 → 5 (Score: 0.0139)
#   - base_model.model.model.layers.20.self_attn.q_proj: r=6 → 5 (Score: 0.0078)
#   - base_model.model.model.layers.20.self_attn.k_proj: r=6 → 5 (Score: 0.0200)
#   - base_model.model.model.layers.20.self_attn.v_proj: r=6 → 5 (Score: 0.0119)
#   - base_model.model.model.layers.20.self_attn.o_proj: r=5 (Unchanged, Score: 0.0000)
#   - base_model.model.model.layers.20.mlp.gate_proj: r=6 (Unchanged, Score: 0.0330)
#   - base_model.model.model.layers.20.mlp.up_proj: r=6 → 5 (Score: 0.0235)
#   - base_model.model.model.layers.20.mlp.down_proj: r=6 → 5 (Score: 0.0235)
#   - base_model.model.model.layers.21.self_attn.q_proj: r=6 → 5 (Score: 0.0060)
#   - base_model.model.model.layers.21.self_attn.k_proj: r=6 (Unchanged, Score: 0.0348)
#   - base_model.model.model.layers.21.self_attn.v_proj: r=6 → 5 (Score: 0.0250)
#   - base_model.model.model.layers.21.self_attn.o_proj: r=5 (Unchanged, Score: 0.0029)
#   - base_model.model.model.layers.21.mlp.gate_proj: r=6 → 5 (Score: 0.0029)
#   - base_model.model.model.layers.21.mlp.up_proj: r=6 → 5 (Score: 0.0008)
#   - base_model.model.model.layers.21.mlp.down_proj: r=6 → 5 (Score: 0.0008)
# ✅ AdaptiveLoRA: Rank setup for Epoch 5 complete.
#
# 📄 Epoch 5: Rank allocations logged to ./logs/adaptive_lora_epoch_logs.csv
# TrainOutput(global_step=1560, training_loss=0.28930461027492316, metrics={'train_runtime': 5335.8018, 'train_samples_per_second': 2.333, 'train_steps_per_second': 0.292, 'total_flos': 1.361882632032768e+16, 'train_loss': 0.28930461027492316, 'epoch': 5.0})

# %%
print("📊 Final Evaluation:")
results = trainer.evaluate()
print(results)
# Out:
# 📊 Final Evaluation:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3273736712.py in <cell line: 0>()
#       1 print("📊 Final Evaluation:")
# ----> 2 results = trainer.evaluate()
#       3 print(results)
#
# NameError: name 'trainer' is not defined
